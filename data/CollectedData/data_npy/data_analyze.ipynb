# %%
import os
import glob
import numpy as np

# %%
data = glob.glob('graph_label/*')

# %%
for name in data:
# Out:
# ['graph_label/graph_label90.npy',
#  'graph_label/graph_label20.npy',
#  'graph_label/graph_label58.npy',
#  'graph_label/graph_label137.npy',
#  'graph_label/graph_label15.npy',
#  'graph_label/graph_label133.npy',
#  'graph_label/graph_label21.npy',
#  'graph_label/graph_label52.npy',
#  'graph_label/graph_label53.npy',
#  'graph_label/graph_label138.npy',
#  'graph_label/graph_label105.npy',
#  'graph_label/graph_label164.npy',
#  'graph_label/graph_label63.npy',
#  'graph_label/graph_label159.npy',
#  'graph_label/graph_label111.npy',
#  'graph_label/graph_label69.npy',
#  'graph_label/graph_label136.npy',
#  'graph_label/graph_label94.npy',
#  'graph_label/graph_label13.npy',
#  'graph_label/graph_label39.npy',
#  'graph_label/graph_label51.npy',
#  'graph_label/graph_label154.npy',
#  'graph_label/graph_label148.npy',
#  'graph_label/graph_label145.npy',
#  'graph_label/graph_label43.npy',
#  'graph_label/graph_label172.npy',
#  'graph_label/graph_label79.npy',
# ...
